# %%
import os
import glob
import pandas as pd
import numpy as np

# %%
os.chdir('C:\\Users\\oreol\\Data-Analysis-Project')
#Changes the directory to the one containing the forked file

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])

# %%
#Combining all the list of files and exporting as csv
combined_csv.to_csv('combined_csv', index=False, encoding='utf-8-sig')
#The .csv command completely converts the files into csv formats

# %%
df = pd.read_csv('combined_csv')

# %%
df
# Out:
#        Invoice ID Branch           City Customer type  Gender  \
# 0     692-92-5582      B          Abuja        Member  Female
# 1     351-62-0822      B          Abuja        Member  Female
# 2     529-56-3974      B          Abuja        Member    Male
# 3     299-46-1805      B          Abuja        Member  Female
# 4     319-50-3348      B          Abuja        Normal  Female
# ...           ...    ...            ...           ...     ...
# 6995  148-41-7930      C  Port Harcourt        Normal    Male
# 6996  189-40-5216      C  Port Harcourt        Normal    Male
# 6997  267-62-7380      C  Port Harcourt        Member    Male
# 6998  652-49-6720      C  Port Harcourt        Member  Female
# 6999  233-67-5758      C  Port Harcourt        Normal    Male
#
#                 Product line  Unit price  Quantity    Tax 5%      Total  \
# 0         Food and beverages     19742.4         3   2961.36   62188.56
# 1        Fashion accessories      5212.8         4   1042.56   21893.76
# ...

# %% [markdown]
# Step 2: Data Exploration

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')  
import warnings
warnings.filterwarnings('ignore')

# %%
#Using the head method to view the first few rows of the dataset
df.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date   Time Payment  \
# 0     19742.4         3   2961.36   62188.56  2/20/2019  13:27    Card
# 1      5212.8         4   1042.56   21893.76   2/6/2019  18:07    Epay
# 2      9183.6         4   1836.72   38571.12   3/9/2019  17:03    Cash
# 3     33739.2         6  10121.76  212556.96  1/15/2019  16:19    Cash
# 4     14508.0         2   1450.80   30466.80  3/11/2019  15:30    Epay
#
#        cogs  gross margin percentage  gross income  Rating
# ...

# %%
#The shape method to determine the number of rows and columns in the dataset with the aid of the shape attribute
df.shape
# Out:
# (7000, 17)

# %%
#The column attribute generates the names of columns in a dataset
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.describe()
#The describe describes only the numeric series alone
# Out:
#          Unit price     Quantity        Tax 5%          Total           cogs  \
# count   7000.000000  7000.000000   7000.000000    7000.000000    7000.000000
# mean   20041.966800     5.510000   5536.572840  116268.029640  110731.456800
# std     9533.977002     2.922177   4213.370023   88480.770486   84267.400463
# min     3628.800000     1.000000    183.060000    3844.260000    3661.200000
# 25%    11835.000000     3.000000   2132.955000   44792.055000   42659.100000
# 50%    19882.800000     5.000000   4351.680000   91385.280000   87033.600000
# 75%    28056.600000     8.000000   8080.290000  169686.090000  161605.800000
# max    35985.600000    10.000000  17874.000000  375354.000000  357480.000000
#
#        gross margin percentage  gross income       Rating
# count             7.000000e+03   7000.000000  7000.000000
# mean              4.761905e+00   5536.572840     6.972700
# std               5.423353e-13   4213.370023     1.717843
# ...

# %% [markdown]
# As shown in the output image, Statistical description of dataframe was returned with the respective passed percentiles.The describe method works only when the data is numeric. It doesn't work for non-numeric data.
# From the statistical summary data, the following can be derived:
# 1. Mean
# 2. Unit Price
# 3. Quantity
# 4. Tax
# 5. Total
# 6. Cogs
# 7. Gross Margin
# 8. Percentage
# 9. Gross Income
# 10. Rating
# They are all numeric data.
#
# The behaviour of describe() is different with series of strings. df.describe(include= 'object')
# df.describe(include= 'float') is used to describe the series of floats in the dataframe

# %%
#Mask of bool values for each element in DataFrame that indicates whether an element is an NA value.
df.isna()
# Out:
#       Invoice ID  Branch   City  Customer type  Gender  Product line  \
# 0          False   False  False          False   False         False
# 1          False   False  False          False   False         False
# 2          False   False  False          False   False         False
# 3          False   False  False          False   False         False
# 4          False   False  False          False   False         False
# ...          ...     ...    ...            ...     ...           ...
# 6995       False   False  False          False   False         False
# 6996       False   False  False          False   False         False
# 6997       False   False  False          False   False         False
# 6998       False   False  False          False   False         False
# 6999       False   False  False          False   False         False
#
#       Unit price  Quantity  Tax 5%  Total   Date   Time  Payment   cogs  \
# ...

# %%
df2 = df.isnull()
df2
#Note that df.isna() is the short form of df.isnull()
# Out:
#       Invoice ID  Branch   City  Customer type  Gender  Product line  \
# 0          False   False  False          False   False         False
# 1          False   False  False          False   False         False
# 2          False   False  False          False   False         False
# 3          False   False  False          False   False         False
# 4          False   False  False          False   False         False
# ...          ...     ...    ...            ...     ...           ...
# 6995       False   False  False          False   False         False
# 6996       False   False  False          False   False         False
# 6997       False   False  False          False   False         False
# 6998       False   False  False          False   False         False
# 6999       False   False  False          False   False         False
#
#       Unit price  Quantity  Tax 5%  Total   Date   Time  Payment   cogs  \
# ...

# %%
df.info()
#This method prints information about a DataFrame including the index dtype and column dtypes, non-null values and memory usage.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               7000 non-null   object
#  1   Branch                   7000 non-null   object
#  2   City                     7000 non-null   object
#  3   Customer type            7000 non-null   object
#  4   Gender                   7000 non-null   object
#  5   Product line             7000 non-null   object
#  6   Unit price               7000 non-null   float64
#  7   Quantity                 7000 non-null   int64
#  8   Tax 5%                   7000 non-null   float64
#  9   Total                    7000 non-null   float64
#  10  Date                     7000 non-null   object
#  11  Time                     7000 non-null   object
#  12  Payment                  7000 non-null   object
#  13  cogs                     7000 non-null   float64
# ...

# %%
df
# Out:
#        Invoice ID Branch           City Customer type  Gender  \
# 0     692-92-5582      B          Abuja        Member  Female
# 1     351-62-0822      B          Abuja        Member  Female
# 2     529-56-3974      B          Abuja        Member    Male
# 3     299-46-1805      B          Abuja        Member  Female
# 4     319-50-3348      B          Abuja        Normal  Female
# ...           ...    ...            ...           ...     ...
# 6995  148-41-7930      C  Port Harcourt        Normal    Male
# 6996  189-40-5216      C  Port Harcourt        Normal    Male
# 6997  267-62-7380      C  Port Harcourt        Member    Male
# 6998  652-49-6720      C  Port Harcourt        Member  Female
# 6999  233-67-5758      C  Port Harcourt        Normal    Male
#
#                 Product line  Unit price  Quantity    Tax 5%      Total  \
# 0         Food and beverages     19742.4         3   2961.36   62188.56
# 1        Fashion accessories      5212.8         4   1042.56   21893.76
# ...

# %%
import datetime as dt

# %%
df['New_date'] = pd.to_datetime(df['Date'], errors='ignore')

# %%
df
# Out:
#        Invoice ID Branch           City Customer type  Gender  \
# 0     692-92-5582      B          Abuja        Member  Female
# 1     351-62-0822      B          Abuja        Member  Female
# 2     529-56-3974      B          Abuja        Member    Male
# 3     299-46-1805      B          Abuja        Member  Female
# 4     319-50-3348      B          Abuja        Normal  Female
# ...           ...    ...            ...           ...     ...
# 6995  148-41-7930      C  Port Harcourt        Normal    Male
# 6996  189-40-5216      C  Port Harcourt        Normal    Male
# 6997  267-62-7380      C  Port Harcourt        Member    Male
# 6998  652-49-6720      C  Port Harcourt        Member  Female
# 6999  233-67-5758      C  Port Harcourt        Normal    Male
#
#                 Product line  Unit price  Quantity    Tax 5%      Total  \
# 0         Food and beverages     19742.4         3   2961.36   62188.56
# 1        Fashion accessories      5212.8         4   1042.56   21893.76
# ...

# %%
df['day']= df['New_date'].dt.day

# %%
#df['New_date'] = df['Date'].dt.strftime('%m-%d-%Y')
df['month']= df['New_date'].dt.month

# %%
df
# Out:
#        Invoice ID Branch           City Customer type  Gender  \
# 0     692-92-5582      B          Abuja        Member  Female
# 1     351-62-0822      B          Abuja        Member  Female
# 2     529-56-3974      B          Abuja        Member    Male
# 3     299-46-1805      B          Abuja        Member  Female
# 4     319-50-3348      B          Abuja        Normal  Female
# ...           ...    ...            ...           ...     ...
# 6995  148-41-7930      C  Port Harcourt        Normal    Male
# 6996  189-40-5216      C  Port Harcourt        Normal    Male
# 6997  267-62-7380      C  Port Harcourt        Member    Male
# 6998  652-49-6720      C  Port Harcourt        Member  Female
# 6999  233-67-5758      C  Port Harcourt        Normal    Male
#
#                 Product line  Unit price  Quantity    Tax 5%      Total  \
# 0         Food and beverages     19742.4         3   2961.36   62188.56
# 1        Fashion accessories      5212.8         4   1042.56   21893.76
# ...

# %%
df['year']= df['New_date'].dt.year

# %%
df
# Out:
#        Invoice ID Branch           City Customer type  Gender  \
# 0     692-92-5582      B          Abuja        Member  Female
# 1     351-62-0822      B          Abuja        Member  Female
# 2     529-56-3974      B          Abuja        Member    Male
# 3     299-46-1805      B          Abuja        Member  Female
# 4     319-50-3348      B          Abuja        Normal  Female
# ...           ...    ...            ...           ...     ...
# 6995  148-41-7930      C  Port Harcourt        Normal    Male
# 6996  189-40-5216      C  Port Harcourt        Normal    Male
# 6997  267-62-7380      C  Port Harcourt        Member    Male
# 6998  652-49-6720      C  Port Harcourt        Member  Female
# 6999  233-67-5758      C  Port Harcourt        Normal    Male
#
#                 Product line  Unit price  Quantity    Tax 5%      Total  ...  \
# 0         Food and beverages     19742.4         3   2961.36   62188.56  ...
# ...

# %%
df['hour'] = pd.to_datetime(df['Time']).dt.hour

# %%
df
# Out:
#        Invoice ID Branch           City Customer type  Gender  \
# 0     692-92-5582      B          Abuja        Member  Female
# 1     351-62-0822      B          Abuja        Member  Female
# 2     529-56-3974      B          Abuja        Member    Male
# 3     299-46-1805      B          Abuja        Member  Female
# 4     319-50-3348      B          Abuja        Normal  Female
# ...           ...    ...            ...           ...     ...
# 6995  148-41-7930      C  Port Harcourt        Normal    Male
# 6996  189-40-5216      C  Port Harcourt        Normal    Male
# 6997  267-62-7380      C  Port Harcourt        Member    Male
# 6998  652-49-6720      C  Port Harcourt        Member  Female
# 6999  233-67-5758      C  Port Harcourt        Normal    Male
#
#                 Product line  Unit price  Quantity    Tax 5%      Total  ...  \
# 0         Food and beverages     19742.4         3   2961.36   62188.56  ...
# ...

# %%
#The unique method is used to determine the number of unique hours of sales in a supermarket and return an array of numbers
arr = df["hour"].unique()

# %%
arr
# Out:
# array([13, 18, 17, 16, 15, 10, 12, 19, 14, 11, 20], dtype=int64)

# %%
#To get a list of the categorical columns in the dataset
#we iterate through the columns and check if each element is an object datatype
categorical_columns = [col for col in df.columns if df[col].dtype == "object" ]
categorical_columns
# Out:
# ['Invoice ID',
#  'Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Date',
#  'Time',
#  'Payment']

# %%
#To generate a list of unique values in the categorical columns
df['Branch'].unique().tolist()
# Out:
# ['B', 'A', 'C']

# %%
print("Total Number of unique values in the Branch Column : {}". format(len(df['Branch'].unique().tolist())))
# Out:
# Total Number of unique values in the Branch Column : 3

# %%
categorical_columns
# Out:
# ['Invoice ID',
#  'Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Date',
#  'Time',
#  'Payment']

# %%
#df['Invoice ID'].unique().tolist()
#df['City'].unique().tolist()
#df['Customer type'].unique().tolist()
#df['Gender'].unique().tolist()
#df['Product line'].unique().tolist()
#df['Date'].unique().tolist()
#df['Time'].unique().tolist()
#df['Payment'].unique().tolist()

# %%
df['Invoice ID'].unique().tolist()
# Out:
# ['692-92-5582',
#  '351-62-0822',
#  '529-56-3974',
#  '299-46-1805',
#  '319-50-3348',
#  '371-85-5789',
#  '273-16-6619',
#  '649-29-6775',
#  '145-94-9061',
#  '871-79-8483',
#  '149-71-6266',
#  '640-49-2076',
#  '777-82-7220',
#  '280-35-5823',
#  '354-25-5821',
#  '132-32-9879',
#  '370-41-7321',
#  '727-46-3608',
#  '669-54-1719',
#  '616-24-2851',
#  '242-55-6721',
#  '347-34-2234',
#  '853-23-2453',
#  '109-28-2512',
#  '510-95-6347',
#  '847-38-7188',
#  '318-68-5053',
#  '152-08-9985',
#  '766-85-7061',
#  '733-01-9107',
#  '716-39-1409',
#  '479-26-8945',
#  '227-78-1148',
#  '291-32-1427',
#  '659-65-8956',
#  '378-24-2715',
#  '219-22-9386',
#  '268-27-6179',
#  '549-84-7482',
#  '191-10-6171',
#  '695-51-0018',
#  '590-83-4591',
#  '241-72-9525',
#  '262-47-2794',
#  '608-96-3517',
#  '279-74-2924',
#  '307-85-2293',
#  '743-04-1105',
#  '423-57-2993',
#  '548-46-9322',
#  '505-02-0892',
#  '316-55-4634',
#  '608-27-6295',
#  '414-12-7047',
#  '895-66-0685',
# ...

# %%
print("Total Number of unique values in the Branch Column : {}". format(len(df['Invoice ID'].unique().tolist())))
# Out:
# Total Number of unique values in the Branch Column : 1000

# %%
df['City'].unique().tolist()
# Out:
# ['Abuja', 'Lagos', 'Port Harcourt']

# %%
print("Total Number of unique values in the Branch Column : {}". format(len(df['City'].unique().tolist())))
# Out:
# Total Number of unique values in the Branch Column : 3

# %%
df['Customer type'].unique().tolist()
# Out:
# ['Member', 'Normal']

# %%
print("Total Number of unique values in the Branch Column : {}". format(len(df['Customer type'].unique().tolist())))
# Out:
# Total Number of unique values in the Branch Column : 2

# %%
df['Gender'].unique().tolist()
# Out:
# ['Female', 'Male']

# %%
print("Total Number of unique values in the Branch Column : {}". format(len(df['Gender'].unique().tolist())))
# Out:
# Total Number of unique values in the Branch Column : 2

# %%
df['Product line'].unique().tolist()
# Out:
# ['Food and beverages',
#  'Fashion accessories',
#  'Electronic accessories',
#  'Sports and travel',
#  'Home and lifestyle',
#  'Health and beauty']

# %%
print("Total Number of unique values in the Branch Column : {}". format(len(df['Product line'].unique().tolist())))
# Out:
# Total Number of unique values in the Branch Column : 6

# %%
df['Date'].unique().tolist()
# Out:
# ['2/20/2019',
#  '2/6/2019',
#  '3/9/2019',
#  '1/15/2019',
#  '3/11/2019',
#  '3/5/2019',
#  '3/15/2019',
#  '2/8/2019',
#  '1/25/2019',
#  '2/25/2019',
#  '1/28/2019',
#  '1/10/2019',
#  '3/3/2019',
#  '1/17/2019',
#  '2/27/2019',
#  '2/10/2019',
#  '3/22/2019',
#  '3/7/2019',
#  '2/3/2019',
#  '2/14/2019',
#  '1/7/2019',
#  '1/26/2019',
#  '3/12/2019',
#  '3/29/2019',
#  '3/19/2019',
#  '2/5/2019',
#  '2/15/2019',
#  '1/16/2019',
#  '1/20/2019',
#  '2/17/2019',
#  '2/16/2019',
#  '3/6/2019',
#  '3/23/2019',
#  '1/4/2019',
#  '3/30/2019',
#  '3/27/2019',
#  '1/19/2019',
#  '1/18/2019',
#  '2/11/2019',
#  '3/28/2019',
#  '3/2/2019',
#  '3/20/2019',
#  '3/24/2019',
#  '2/12/2019',
#  '3/10/2019',
#  '1/31/2019',
#  '2/26/2019',
#  '2/21/2019',
#  '2/2/2019',
#  '2/9/2019',
#  '1/14/2019',
#  '1/29/2019',
#  '3/13/2019',
#  '1/8/2019',
#  '1/24/2019',
#  '2/23/2019',
#  '2/7/2019',
#  '2/24/2019',
#  '3/14/2019',
#  '3/1/2019',
#  '3/16/2019',
#  '1/5/2019',
#  '1/30/2019',
# ...

# %%
print("Total Number of unique values in the Branch Column : {}". format(len(df['Date'].unique().tolist())))
# Out:
# Total Number of unique values in the Branch Column : 89

# %%
df['Time'].unique().tolist()
# Out:
# ['13:27',
#  '18:07',
#  '17:03',
#  '16:19',
#  '15:30',
#  '10:40',
#  '12:20',
#  '15:31',
#  '19:48',
#  '19:39',
#  '12:43',
#  '14:49',
#  '13:01',
#  '18:45',
#  '13:03',
#  '18:00',
#  '17:24',
#  '15:47',
#  '12:45',
#  '14:42',
#  '11:49',
#  '13:40',
#  '14:35',
#  '15:01',
#  '18:17',
#  '19:56',
#  '17:55',
#  '12:09',
#  '10:25',
#  '18:14',
#  '18:19',
#  '11:32',
#  '12:44',
#  '12:29',
#  '15:26',
#  '20:38',
#  '17:26',
#  '14:57',
#  '11:15',
#  '13:18',
#  '18:36',
#  '14:40',
#  '12:21',
#  '15:07',
#  '19:20',
#  '19:40',
#  '13:58',
#  '14:43',
#  '19:18',
#  '15:24',
#  '14:12',
#  '17:34',
#  '12:04',
#  '19:46',
#  '19:00',
#  '10:53',
#  '10:39',
#  '13:41',
#  '20:23',
#  '11:57',
#  '14:51',
#  '12:42',
#  '19:42',
#  '19:17',
#  '13:24',
#  '15:53',
#  '18:27',
#  '12:58',
#  '18:59',
#  '13:44',
#  '13:46',
#  '19:14',
#  '10:52',
#  '19:28',
#  '13:52',
#  '10:54',
#  '18:31',
#  '19:26',
#  '18:42',
#  '19:43',
#  '19:06',
#  '15:34',
#  '19:22',
# ...

# %%
print("Total Number of unique values in the Branch Column : {}". format(len(df['Time'].unique().tolist())))
# Out:
# Total Number of unique values in the Branch Column : 506

# %%
df['Payment'].unique().tolist()
# Out:
# ['Card', 'Epay', 'Cash']

# %%
print("Total Number of unique values in the Branch Column : {}". format(len(df['Payment'].unique().tolist())))
# Out:
# Total Number of unique values in the Branch Column : 3

# %%
df['City'].value_counts()
# Out:
# Lagos            2380
# Abuja            2324
# Port Harcourt    2296
# Name: City, dtype: int64

# %%
df['Payment'].value_counts()
# Out:
# Epay    2415
# Cash    2408
# Card    2177
# Name: Payment, dtype: int64

# %%
df['Date'].value_counts()
# Out:
# 2/7/2019     140
# 2/15/2019    133
# 3/2/2019     126
# 1/8/2019     126
# 3/14/2019    126
#             ...
# 2/1/2019      42
# 1/4/2019      42
# 2/28/2019     42
# 2/21/2019     42
# 3/21/2019     42
# Name: Date, Length: 89, dtype: int64

# %%
df['Branch'].value_counts()
# Out:
# A    2380
# B    2324
# C    2296
# Name: Branch, dtype: int64

# %%
df['Product line'].value_counts()
# Out:
# Fashion accessories       1246
# Food and beverages        1218
# Electronic accessories    1190
# Sports and travel         1162
# Home and lifestyle        1120
# Health and beauty         1064
# Name: Product line, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Female    3507
# Male      3493
# Name: Gender, dtype: int64

# %%
df['Customer type'].value_counts()
# Out:
# Member    3507
# Normal    3493
# Name: Customer type, dtype: int64

# %%
df
# Out:
#        Invoice ID Branch           City Customer type  Gender  \
# 0     692-92-5582      B          Abuja        Member  Female
# 1     351-62-0822      B          Abuja        Member  Female
# 2     529-56-3974      B          Abuja        Member    Male
# 3     299-46-1805      B          Abuja        Member  Female
# 4     319-50-3348      B          Abuja        Normal  Female
# ...           ...    ...            ...           ...     ...
# 6995  148-41-7930      C  Port Harcourt        Normal    Male
# 6996  189-40-5216      C  Port Harcourt        Normal    Male
# 6997  267-62-7380      C  Port Harcourt        Member    Male
# 6998  652-49-6720      C  Port Harcourt        Member  Female
# 6999  233-67-5758      C  Port Harcourt        Normal    Male
#
#                 Product line  Unit price  Quantity    Tax 5%      Total  ...  \
# 0         Food and beverages     19742.4         3   2961.36   62188.56  ...
# ...

# %%
#Grouping the dataframe with the City column
df3 = df.groupby('City')

# %%
df3['Total'].mean()
# Out:
# City
# Abuja            115154.102169
# Lagos            112447.451118
# Port Harcourt    121355.897378
# Name: Total, dtype: float64

# %%
df4 = df3['Total'].sum()

# %%
df4
# Out:
# City
# Abuja            2.676181e+08
# Lagos            2.676249e+08
# Port Harcourt    2.786331e+08
# Name: Total, dtype: float64

# %%
df4.max()
# Out:
# 278633140.3799998

# %% [markdown]
# ##The city with the highest total gross income is Port Harcourt

# %%
sns.countplot(x='Branch', data=df)
#This shows that the branch with the highest sales record is Branch A
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='count'>

# %%
sns.countplot(x='Payment', data=df)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='count'>

# %%
sns.countplot(x='City', data=df)
# Out:
# <AxesSubplot:xlabel='City', ylabel='count'>

# %%
sns.countplot(y='Product line', data=df)
#This shows that the highest Product line is Fashion accessories 
#While the lowest product line is Health and Beauty
# Out:
# <AxesSubplot:xlabel='count', ylabel='Product line'>

# %%
#To determine the payment channel for each branch
sns.countplot(x='Branch', hue='Payment', data=df)
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='count'>

# %%
#boxplot = df.boxplot(figsize = (10,10), rot = 90, fontsize= '8', grid = False)
sns.boxplot(x='Branch', y='Rating', data=df)
#This is used to determine the branch with the lowest rating
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='Rating'>

# %%
#The branch with the lowest rating is Branch B

# %%
#Using a catplot() to generate visualization for the "product line" on x-axis, quantity on the y-axis, and hue as gender.
sns.catplot(x='Product line', y='Quantity', hue='Gender', aspect=4, data=df)

# %%
#From the above, we can see that the catplot 
#shows the relationship between a numerical and one or more categorical 
#variables using one of several visual representations.

# %%
#Using a catplot() to generate visualization for the "product line" on x-axis, Total on the y-axis, and hue as gender.
sns.catplot(x='Product line', y='Total', hue='Gender', aspect=4, data=df)

# %%
#Product line per unit price
sns.catplot(x='Product line', y='Unit price', kind='point', aspect=4, data=df)

# %%
#Product line per Quantity
sns.catplot(x='Product line', y='Quantity', kind='point', aspect=4, data=df)
